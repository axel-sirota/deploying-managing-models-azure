# %%
import os
import azureml.core
from azureml.core import Workspace, Dataset, Datastore, ComputeTarget, Experiment, ScriptRunConfig
from azureml.pipeline.steps import PythonScriptStep
from azureml.pipeline.core import Pipeline
# check core SDK version number
print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  1.37.0

# %%
workspace = Workspace.from_config()
print('Workspace name: ' + workspace.name, 
      'Azure region: ' + workspace.location, 
      'Subscription id: ' + workspace.subscription_id, 
      'Resource group: ' + workspace.resource_group, sep='\n')
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# The default web browser has been opened at https://login.microsoftonline.com/organizations/oauth2/v2.0/authorize. Please continue the login in the web browser. If no web browser is available or if the web browser fails to open, use device code flow with `az login --use-device-code`.
# Interactive authentication successfully completed.
# Workspace name: basic-ws-2
# Azure region: eastus
# Subscription id: 790907ce-38df-431c-9fce-11b9ec68781d
# Resource group: test

# %%
# create an ML experiment
exp = Experiment(workspace=workspace, name='keras-mnist-fashion')

# create a directory
script_folder = './keras-mnist-fashion'
os.makedirs(script_folder, exist_ok=True)

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# choose a name for your cluster
cluster_name = "gpu-cluster"

try:
    compute_target = ComputeTarget(workspace=workspace, name=cluster_name)
    print('Found existing compute target')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_NC6', 
                                                           max_nodes=4)

    # create the cluster
    compute_target = ComputeTarget.create(workspace, cluster_name, compute_config)

    # can poll for a minimum number of nodes and for a specific timeout. 
    # if no min node count is provided it uses the scale settings for the cluster
    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)

# use get_status() to get a detailed status for the current cluster. 
print(compute_target.get_status().serialize())
# Out:
# Creating a new compute target...
# InProgress.
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned
# {'currentNodeCount': 0, 'targetNodeCount': 0, 'nodeStateCounts': {'preparingNodeCount': 0, 'runningNodeCount': 0, 'idleNodeCount': 0, 'unusableNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0}, 'allocationState': 'Resizing', 'allocationStateTransitionTime': '2021-12-14T00:11:49.623000+00:00', 'errors': None, 'creationTime': '2021-12-14T00:11:49.166964+00:00', 'modifiedTime': '2021-12-14T00:11:54.760273+00:00', 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 4, 'nodeIdleTimeBeforeScaleDown': 'PT1800S'}, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_NC6'}

# %%
data_urls = ['https://data4mldemo6150520719.blob.core.windows.net/demo/mnist-fashion']
fashion_ds = Dataset.File.from_files(data_urls)

# list the files referenced by fashion_ds
fashion_ds.to_path()
# Out:
# ['/mnist-fashion/t10k-images-idx3-ubyte',
#  '/mnist-fashion/t10k-labels-idx1-ubyte',
#  '/mnist-fashion/train-images-idx3-ubyte',
#  '/mnist-fashion/train-labels-idx1-ubyte']

# %%
from azureml.data import OutputFileDatasetConfig

datastore=workspace.get_default_datastore()
prepared_fashion_ds = OutputFileDatasetConfig(destination=(datastore, 'outputdataset/{run-id}')).register_on_complete(name='prepared_fashion_ds')

# %%
prep_step = PythonScriptStep(name='prepare step',
                             script_name="prepare.py",
                             # mount fashion_ds dataset to the compute_target
                             arguments=[fashion_ds.as_named_input('fashion_ds').as_mount(), prepared_fashion_ds],
                             source_directory=script_folder,
                             compute_target=compute_target,
                             allow_reuse=True)

# %%
# %%writefile conda_dependencies.yml
#
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core
#   - azureml-dataset-runtime
#   - keras==2.4.3
#   - tensorflow==2.4.3
#   - numpy
#   - scikit-learn
#   - pandas
#   - matplotlib
# Out:
# Writing conda_dependencies.yml

# %%
from azureml.core import Environment

keras_env = Environment.from_conda_specification(name = 'keras-env', file_path = './conda_dependencies.yml')

# %%
train_src = ScriptRunConfig(source_directory=script_folder,
                            script='train.py',
                            compute_target=compute_target,
                            environment=keras_env)

# %%
train_step = PythonScriptStep(name='train step',
                              arguments=[prepared_fashion_ds.read_delimited_files().as_input(name='prepared_fashion_ds')],
                              source_directory=train_src.source_directory,
                              script_name=train_src.script,
                              runconfig=train_src.run_config)

# %%
# build pipeline & run experiment
pipeline = Pipeline(workspace, steps=[prep_step, train_step])
run = exp.submit(pipeline)
# Out:
# Created step prepare step [39b13515][877685a0-4903-438a-8a30-0261f380e544], (This step will run and generate new outputs)Created step train step [600ab4e1][8ff6582c-1c97-4741-b72b-8d8cde628cee], (This step will run and generate new outputs)
#
# Submitted PipelineRun 39236fa9-d0ba-46c0-a840-02debd38aa04
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/39236fa9-d0ba-46c0-a840-02debd38aa04?wsid=/subscriptions/790907ce-38df-431c-9fce-11b9ec68781d/resourcegroups/test/workspaces/basic-ws-2&tid=5100e2c5-9fd5-492c-8e65-b9e2a0d8584f

# %%
run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 39236fa9-d0ba-46c0-a840-02debd38aa04
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/39236fa9-d0ba-46c0-a840-02debd38aa04?wsid=/subscriptions/790907ce-38df-431c-9fce-11b9ec68781d/resourcegroups/test/workspaces/basic-ws-2&tid=5100e2c5-9fd5-492c-8e65-b9e2a0d8584f
# PipelineRun Status: Running
#
#
# StepRunId: 55844d80-1a7a-4532-bac2-8c68f1197a86
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/55844d80-1a7a-4532-bac2-8c68f1197a86?wsid=/subscriptions/790907ce-38df-431c-9fce-11b9ec68781d/resourcegroups/test/workspaces/basic-ws-2&tid=5100e2c5-9fd5-492c-8e65-b9e2a0d8584f
# StepRun( prepare step ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/12/14 00:13:02 Downloading source code...
# 2021/12/14 00:13:03 Finished downloading source code
# 2021/12/14 00:13:03 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/12/14 00:13:04 Successfully set up Docker network: acb_default_network
# 2021/12/14 00:13:04 Setting up Docker configuration...
# 2021/12/14 00:13:04 Successfully set up Docker configuration
# 2021/12/14 00:13:04 Logging in to registry: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io
# 2021/12/14 00:13:05 Successfully logged into 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io
# 2021/12/14 00:13:05 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/12/14 00:13:05 Scanning for dependencies...
# 2021/12/14 00:13:06 Successfully scanned dependencies
# 2021/12/14 00:13:06 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1@sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1@sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 284055322776: Already exists
# 56c2761c3a56: Pulling fs layer
# e7dff8330ff9: Pulling fs layer
# c782690959f6: Pulling fs layer
# 722c34119f7e: Pulling fs layer
# 2df507734fe8: Pulling fs layer
# 858f3d745b66: Pulling fs layer
# 7c1ed34d7266: Pulling fs layer
# 1ef5f8a4fad5: Pulling fs layer
# 722c34119f7e: Waiting
# 2df507734fe8: Waiting
# 858f3d745b66: Waiting
# 7c1ed34d7266: Waiting
# 1ef5f8a4fad5: Waiting
# c782690959f6: Verifying Checksum
# c782690959f6: Download complete
# e7dff8330ff9: Verifying Checksum
# e7dff8330ff9: Download complete
# 2df507734fe8: Verifying Checksum
# 2df507734fe8: Download complete
# 858f3d745b66: Verifying Checksum
# 858f3d745b66: Download complete
# 7c1ed34d7266: Verifying Checksum
# 7c1ed34d7266: Download complete
# 1ef5f8a4fad5: Download complete
# 56c2761c3a56: Verifying Checksum
# 56c2761c3a56: Download complete
# 722c34119f7e: Verifying Checksum
# 722c34119f7e: Download complete
# 56c2761c3a56: Pull complete
# e7dff8330ff9: Pull complete
# c782690959f6: Pull complete
# 722c34119f7e: Pull complete
# 2df507734fe8: Pull complete
# 858f3d745b66: Pull complete
# 7c1ed34d7266: Pull complete
# 1ef5f8a4fad5: Pull complete
# Digest: sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1@sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
#  ---> 332d3aa8a60a
# Step 2/19 : USER root
#  ---> Running in d9565a1d29b2
# Removing intermediate container d9565a1d29b2
#  ---> 350f01ff1805
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in 62d0bf181296
# Removing intermediate container 62d0bf181296
#  ---> e6eef357a7a5
# Step 4/19 : WORKDIR /
#  ---> Running in 2f588617877f
# Removing intermediate container 2f588617877f
#  ---> d8c966bf190d
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 5e3be6454348
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in b3d05993b0b4
# Removing intermediate container b3d05993b0b4
#  ---> 3b8a2765c111
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 0b2118ea2aa2
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in c6e56ecd5852
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | #3         |  13%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##5        |  25%
# python-3.6.2         | 27.0 MB   | ####2      |  42%
# python-3.6.2         | 27.0 MB   | #####      |  51%
# python-3.6.2         | 27.0 MB   | #####8     |  59%
# python-3.6.2         | 27.0 MB   | ######7    |  67%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #######6   |  77%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.isuydzio.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.37.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-inference-server-http~=0.4.1
#   Downloading azureml_inference_server_http-0.4.2-py3-none-any.whl (38 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.37.0
#   Downloading azureml_dataset_runtime-1.37.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-core~=1.37.0
#   Downloading azureml_core-1.37.0-py3-none-any.whl (2.5 MB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting gunicorn==20.1.0; platform_system != "Windows"
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting numpy!=1.19.3; sys_platform == "linux"
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting azureml-dataprep<2.26.0a,>=2.25.0a
#   Downloading azureml_dataprep-2.25.0-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting humanfriendly<10.0,>=4.7
#   Downloading humanfriendly-9.2-py2.py3-none-any.whl (86 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.8.1-py2.py3-none-any.whl (206 kB)
# Collecting azure-mgmt-storage<20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-19.0.0-py2.py3-none-any.whl (1.8 MB)
# Collecting pkginfo
#   Downloading pkginfo-1.8.2-py2.py3-none-any.whl (26 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting urllib3<=1.26.7,>=1.23
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting azure-mgmt-resource<20.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-19.0.0-py2.py3-none-any.whl (2.2 MB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pyopenssl<22.0.0
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.2.0-py2.py3-none-any.whl (928 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting msal-extensions<0.4,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting pytz
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Collecting packaging<22.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting argcomplete~=1.8
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.16.0-py2.py3-none-any.whl (78 kB)
# Collecting azure-core<1.21
#   Downloading azure_core-1.20.1-py2.py3-none-any.whl (177 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting knack~=0.8.2
#   Downloading knack-0.8.2-py3-none-any.whl (59 kB)
# Collecting click>=5.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting Werkzeug>=0.14
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
# Requirement already satisfied, skipping upgrade: setuptools>=3.0 in /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib/python3.6/site-packages (from gunicorn==20.1.0; platform_system != "Windows"->azureml-inference-server-http~=0.4.1->azureml-defaults->-r /azureml-environment-setup/condaenv.isuydzio.requirements.txt (line 1)) (50.3.0.post20201006)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting azureml-dataprep-rslex~=2.1.0dev0
#   Downloading azureml_dataprep_rslex-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (13.2 MB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.22-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.37.0->azureml-defaults->-r /azureml-environment-setup/condaenv.isuydzio.requirements.txt (line 1)) (2020.6.20)
# Collecting portalocker<3,>=1.0; python_version >= "3.5" and platform_system != "Windows"
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.6-py3-none-any.whl (97 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.3-py3-none-any.whl (53 kB)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.9-py3-none-any.whl (39 kB)
# Collecting PySocks!=1.5.7,>=1.5.6; extra == "socks"
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting importlib-metadata<5,>=0.23; python_version == "3.6"
#   Downloading importlib_metadata-4.8.2-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting pygments
#   Downloading Pygments-2.10.0-py3-none-any.whl (1.0 MB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Collecting dataclasses; python_version < "3.7"
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-4.0.1-py3-none-any.whl (22 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=60b8a3a0a06f29f299d4b7f1fc9ea1611a9ef72abcd3875bc2f4946dda520e52
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=d836ce5c9ae77cf80070d58bb53eb1c6f40c3f8b63d6d7e2486b07cbe47d7635
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69876 sha256=c73199e93c157bbf85ecb92d0fb0c0f8594e061a01698edc3568ed348d65eb27
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built json-logging-py fusepy wrapt
# Installing collected packages: zipp, typing-extensions, importlib-metadata, click, itsdangerous, MarkupSafe, Jinja2, dataclasses, Werkzeug, flask, gunicorn, applicationinsights, wrapt, pytz, six, python-dateutil, inference-schema, azureml-inference-server-http, configparser, json-logging-py, numpy, azureml-dataprep-rslex, urllib3, idna, charset-normalizer, PySocks, requests, azure-core, portalocker, pycparser, cffi, cryptography, PyJWT, msal, msal-extensions, azure-identity, azureml-dataprep-native, distro, dotnetcore2, cloudpickle, azureml-dataprep, pyarrow, fusepy, azureml-dataset-runtime, backports.weakref, backports.tempfile, humanfriendly, bcrypt, pynacl, paramiko, azure-mgmt-core, azure-common, isodate, oauthlib, requests-oauthlib, msrest, azure-mgmt-storage, pkginfo, pyopenssl, pyasn1, ndg-httpsclient, adal, msrestazure, azure-mgmt-authorization, contextlib2, jeepney, SecretStorage, azure-mgmt-keyvault, azure-mgmt-resource, azure-mgmt-containerregistry, azure-graphrbac, pathspec, pyparsing, packaging, websocket-client, docker, jmespath, argcomplete, jsonpickle, pygments, tabulate, pyyaml, colorama, knack, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.3.0 PySocks-1.7.1 SecretStorage-3.3.1 Werkzeug-2.0.2 adal-1.2.7 applicationinsights-0.11.10 argcomplete-1.12.3 azure-common-1.1.27 azure-core-1.20.1 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.2.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.3.0 azure-mgmt-resource-19.0.0 azure-mgmt-storage-19.0.0 azureml-core-1.37.0 azureml-dataprep-2.25.0 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.1.0 azureml-dataset-runtime-1.37.0 azureml-defaults-1.37.0 azureml-inference-server-http-0.4.2 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.0 cffi-1.15.0 charset-normalizer-2.0.9 click-8.0.3 cloudpickle-1.6.0 colorama-0.4.4 configparser-3.7.4 contextlib2-21.6.0 cryptography-3.4.8 dataclasses-0.8 distro-1.6.0 docker-5.0.3 dotnetcore2-2.1.22 flask-1.0.3 fusepy-3.0.1 gunicorn-20.1.0 humanfriendly-9.2 idna-3.3 importlib-metadata-4.8.2 inference-schema-1.3.0 isodate-0.6.1 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 knack-0.8.2 msal-1.16.0 msal-extensions-0.3.1 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.5 oauthlib-3.1.1 packaging-21.3 paramiko-2.8.1 pathspec-0.9.0 pkginfo-1.8.2 portalocker-2.3.2 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.21 pygments-2.10.0 pynacl-1.4.0 pyopenssl-21.0.0 pyparsing-3.0.6 python-dateutil-2.8.2 pytz-2021.3 pyyaml-6.0 requests-2.26.0 requests-oauthlib-1.3.0 six-1.16.0 tabulate-0.8.9 typing-extensions-4.0.1 urllib3-1.26.7 websocket-client-1.2.3 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container c6e56ecd5852
#  ---> a3c471cec1f7
# Step 9/19 : ENV PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin:$PATH
#  ---> Running in ea044fd1fb60
# Removing intermediate container ea044fd1fb60
#  ---> 8d0a7e7eb43d
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 1347ffedfe12
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in af99af5594f0
# Copying environment context
# Removing intermediate container af99af5594f0
#  ---> 1373873109e2
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 786ff13b141d
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
#  ---> Running in c3c744f451c5
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container c3c744f451c5
#  ---> 7cb31bc910b2
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
#  ---> Running in 8b7f73df6383
# Removing intermediate container 8b7f73df6383
#  ---> 00a2116058c4
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib:$LD_LIBRARY_PATH
#  ---> Running in 1305d8c2612a
# Removing intermediate container 1305d8c2612a
#  ---> d6c2b5070bd9
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> ba1d6742d5c6
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in d70f7d013f8c
# Removing intermediate container d70f7d013f8c
#  ---> 722b4fca1aa4
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 7428953c9185
# Removing intermediate container 7428953c9185
#  ---> ddc73091496a
# Step 19/19 : CMD ["bash"]
#  ---> Running in 633d6bf7b83d
# Removing intermediate container 633d6bf7b83d
#  ---> 19a5ac4c1fdf
# Successfully built 19a5ac4c1fdf
# Successfully tagged 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8:latest
# Successfully tagged 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8:1
# 2021/12/14 00:15:25 Successfully executed container: acb_step_0
# 2021/12/14 00:15:25 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/12/14 00:15:25 Pushing image: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8:1, attempt 1
# The push refers to repository [3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8]
# 9cc644ea9859: Preparing
# 58a82f9924e4: Preparing
# 9867a77fcf93: Preparing
# 1f382d26209b: Preparing
# cd9b0f0b4735: Preparing
# 5a18c8518a57: Preparing
# bde63544efc3: Preparing
# 101366d9cbc2: Preparing
# c8e83c4d4c64: Preparing
# 3c50432f3f31: Preparing
# 311c5d6a5fbd: Preparing
# 510d9bebb038: Preparing
# ae7a6b62e247: Preparing
# 98fed88a80e7: Preparing
# e2015ea1a701: Preparing
# f7df5bbbf80f: Preparing
# 17773ff7b0e9: Preparing
# 824bf068fd3d: Preparing
# 5a18c8518a57: Waiting
# bde63544efc3: Waiting
# 101366d9cbc2: Waiting
# c8e83c4d4c64: Waiting
# 3c50432f3f31: Waiting
# 311c5d6a5fbd: Waiting
# 510d9bebb038: Waiting
# ae7a6b62e247: Waiting
# 98fed88a80e7: Waiting
# e2015ea1a701: Waiting
# f7df5bbbf80f: Waiting
# 17773ff7b0e9: Waiting
# 824bf068fd3d: Waiting
# 9cc644ea9859: Pushed
# 9867a77fcf93: Pushed
# 1f382d26209b: Pushed
# 58a82f9924e4: Pushed
# bde63544efc3: Pushed
# 101366d9cbc2: Pushed
# 5a18c8518a57: Pushed
# c8e83c4d4c64: Pushed
# 3c50432f3f31: Pushed
# 311c5d6a5fbd: Pushed
# ae7a6b62e247: Pushed
# 510d9bebb038: Pushed
# e2015ea1a701: Pushed
# f7df5bbbf80f: Pushed
# 824bf068fd3d: Pushed
# 98fed88a80e7: Pushed
#
# 17773ff7b0e9: Pushed
#
# cd9b0f0b4735: Pushed
# 1: digest: sha256:9d979cc92c836b4cb63d8a4db9df729f3500be3d7ce60acce506c88fa49b5be6 size: 4100
# 2021/12/14 00:16:18 Successfully pushed image: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8:1
# 2021/12/14 00:16:18 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/12/14 00:16:18 Pushing image: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8:latest, attempt 1
# The push refers to repository [3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8]
# 9cc644ea9859: Preparing
# 58a82f9924e4: Preparing
# 9867a77fcf93: Preparing
# 1f382d26209b: Preparing
# cd9b0f0b4735: Preparing
# 5a18c8518a57: Preparing
# bde63544efc3: Preparing
# 101366d9cbc2: Preparing
# c8e83c4d4c64: Preparing
# 3c50432f3f31: Preparing
# 311c5d6a5fbd: Preparing
# 510d9bebb038: Preparing
# ae7a6b62e247: Preparing
# 98fed88a80e7: Preparing
# e2015ea1a701: Preparing
# f7df5bbbf80f: Preparing
# 17773ff7b0e9: Preparing
# 824bf068fd3d: Preparing
# 5a18c8518a57: Waiting
# bde63544efc3: Waiting
# 101366d9cbc2: Waiting
# c8e83c4d4c64: Waiting
# e2015ea1a701: Waiting
# 3c50432f3f31: Waiting
# f7df5bbbf80f: Waiting
# 311c5d6a5fbd: Waiting
# 17773ff7b0e9: Waiting
# 510d9bebb038: Waiting
# ae7a6b62e247: Waiting
# 824bf068fd3d: Waiting
# 98fed88a80e7: Waiting
# 58a82f9924e4: Layer already exists
# cd9b0f0b4735: Layer already exists
# 5a18c8518a57: Layer already exists
# bde63544efc3: Layer already exists
# 101366d9cbc2: Layer already exists
# c8e83c4d4c64: Layer already exists
# 3c50432f3f31: Layer already exists
# 311c5d6a5fbd: Layer already exists
# 510d9bebb038: Layer already exists
# ae7a6b62e247: Layer already exists
# 98fed88a80e7: Layer already exists
# e2015ea1a701: Layer already exists
# f7df5bbbf80f: Layer already exists
# 17773ff7b0e9: Layer already exists
# 824bf068fd3d: Layer already exists
# 1f382d26209b: Layer already exists
# 9867a77fcf93: Layer already exists
# 9cc644ea9859: Layer already exists
# latest: digest: sha256:9d979cc92c836b4cb63d8a4db9df729f3500be3d7ce60acce506c88fa49b5be6 size: 4100
# 2021/12/14 00:16:20 Successfully pushed image: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8:latest
# 2021/12/14 00:16:20 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 139.511681)
# 2021/12/14 00:16:20 Populating digests for step ID: acb_step_0...
# 2021/12/14 00:16:22 Successfully populated digests for step ID: acb_step_0
# 2021/12/14 00:16:22 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 53.605755)
# 2021/12/14 00:16:22 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.058513)
# 2021/12/14 00:16:22 The following dependencies were found:
# 2021/12/14 00:16:22
# - image:
#     registry: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io
#     repository: azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8
#     tag: latest
#     digest: sha256:9d979cc92c836b4cb63d8a4db9df729f3500be3d7ce60acce506c88fa49b5be6
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20211124.v1
#     digest: sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
#   git: {}
# - image:
#     registry: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io
#     repository: azureml/azureml_81b529c865ec40e6b6966fbeb2e3fcf8
#     tag: "1"
#     digest: sha256:9d979cc92c836b4cb63d8a4db9df729f3500be3d7ce60acce506c88fa49b5be6
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20211124.v1
#     digest: sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
#   git: {}
#
#
# Run ID: ca7 was successful after 3m21s
#
# StepRun(prepare step) Execution Summary
# ========================================
# StepRun( prepare step ) Status: Finished
#
# Warnings:
# This run might be using a new job runtime with improved performance and error reporting. The logs from your script are in user_logs/std_log.txt. Please let us know if you run into any issues, and if you would like to opt-out, please add the environment variable AZUREML_COMPUTE_USE_COMMON_RUNTIME to the environment variables section of the job and set its value to the string "false"
# {'runId': '55844d80-1a7a-4532-bac2-8c68f1197a86', 'target': 'gpu-cluster', 'status': 'Completed', 'startTimeUtc': '2021-12-14T00:23:03.558673Z', 'endTimeUtc': '2021-12-14T00:24:26.634066Z', 'services': {}, 'warnings': [{'message': 'This run might be using a new job runtime with improved performance and error reporting. The logs from your script are in user_logs/std_log.txt. Please let us know if you run into any issues, and if you would like to opt-out, please add the environment variable AZUREML_COMPUTE_USE_COMMON_RUNTIME to the environment variables section of the job and set its value to the string "false"'}], 'properties': {'ContentSnapshotId': '652ac928-f31c-4986-85cc-0966f10e110c', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '877685a0-4903-438a-8a30-0261f380e544', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '39b13515', 'azureml.pipelinerunid': '39236fa9-d0ba-46c0-a840-02debd38aa04', 'azureml.pipeline': '39236fa9-d0ba-46c0-a840-02debd38aa04', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '7fd1efb3-6613-4a35-bc67-b68323d31705'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'fashion_ds', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': '9fca0b79-8cfa-44c7-85cc-cf5f59539657', 'registeredId': '6a56c436-d9cf-4513-bc62-d71cb104f468', 'registeredVersion': '1'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'output_6f2105fd'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'outputdataset/55844d80-1a7a-4532-bac2-8c68f1197a86')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "9fca0b79-8cfa-44c7-85cc-cf5f59539657",
#     "name": "prepared_fashion_ds",
#     "version": 1,
#     "workspace": "Workspace.create(name='basic-ws-2', subscription_id='790907ce-38df-431c-9fce-11b9ec68781d', resource_group='test')"
#   }
# }}], 'runDefinition': {'script': 'prepare.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['DatasetConsumptionConfig:fashion_ds', 'DatasetOutputConfig:output_6f2105fd'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'gpu-cluster', 'dataReferences': {}, 'data': {'fashion_ds': {'dataLocation': {'dataset': {'id': '7fd1efb3-6613-4a35-bc67-b68323d31705', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'fashion_ds', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'output_6f2105fd': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'outputdataset/{run-id}'}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': 'prepared_fashion_ds', 'description': None, 'tags': None, 'properties': {'azureml.pipelineRunId': '39236fa9-d0ba-46c0-a840-02debd38aa04', 'azureml.pipelineRun.moduleNodeId': '39b13515', 'azureml.pipelineRun.outputPortName': 'output_6f2105fd'}, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment keras-mnist-fashion Environment', 'version': 'Autosave_2021-12-14T00:12:57Z_4e62ca21', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}], 'name': 'azureml_da3e97fcb51801118b8e80207f3e01ad'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': []}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://basicws2storage0fbba2762.blob.core.windows.net/azureml/ExperimentRun/dcid.55844d80-1a7a-4532-bac2-8c68f1197a86/azureml-logs/20_image_build_log.txt?sv=201 ...
#
#
#
#
# StepRunId: bbd04b2a-d9a0-44d8-af56-6efd5c34f50a
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/bbd04b2a-d9a0-44d8-af56-6efd5c34f50a?wsid=/subscriptions/790907ce-38df-431c-9fce-11b9ec68781d/resourcegroups/test/workspaces/basic-ws-2&tid=5100e2c5-9fd5-492c-8e65-b9e2a0d8584f
# StepRun( train step ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/12/14 00:24:35 Downloading source code...
# 2021/12/14 00:24:36 Finished downloading source code
# 2021/12/14 00:24:36 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/12/14 00:24:36 Successfully set up Docker network: acb_default_network
# 2021/12/14 00:24:36 Setting up Docker configuration...
# 2021/12/14 00:24:37 Successfully set up Docker configuration
# 2021/12/14 00:24:37 Logging in to registry: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io
# 2021/12/14 00:24:38 Successfully logged into 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io
# 2021/12/14 00:24:38 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/12/14 00:24:38 Scanning for dependencies...
# 2021/12/14 00:24:38 Successfully scanned dependencies
# 2021/12/14 00:24:38 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1@sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1@sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 284055322776: Already exists
# 56c2761c3a56: Pulling fs layer
# e7dff8330ff9: Pulling fs layer
# c782690959f6: Pulling fs layer
# 722c34119f7e: Pulling fs layer
# 2df507734fe8: Pulling fs layer
# 858f3d745b66: Pulling fs layer
# 7c1ed34d7266: Pulling fs layer
# 1ef5f8a4fad5: Pulling fs layer
# 722c34119f7e: Waiting
# 2df507734fe8: Waiting
# 858f3d745b66: Waiting
# 7c1ed34d7266: Waiting
# 1ef5f8a4fad5: Waiting
# c782690959f6: Verifying Checksum
# c782690959f6: Download complete
# e7dff8330ff9: Verifying Checksum
# e7dff8330ff9: Download complete
# 2df507734fe8: Verifying Checksum
# 2df507734fe8: Download complete
# 858f3d745b66: Verifying Checksum
# 858f3d745b66: Download complete
# 56c2761c3a56: Verifying Checksum
# 56c2761c3a56: Download complete
# 7c1ed34d7266: Verifying Checksum
# 7c1ed34d7266: Download complete
# 1ef5f8a4fad5: Download complete
# 722c34119f7e: Verifying Checksum
# 722c34119f7e: Download complete
# 56c2761c3a56: Pull complete
# e7dff8330ff9: Pull complete
# c782690959f6: Pull complete
# 722c34119f7e: Pull complete
# 2df507734fe8: Pull complete
# 858f3d745b66: Pull complete
# 7c1ed34d7266: Pull complete
# 1ef5f8a4fad5: Pull complete
# Digest: sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1@sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
#  ---> 332d3aa8a60a
# Step 2/19 : USER root
#  ---> Running in b8dd940308ab
# Removing intermediate container b8dd940308ab
#  ---> ca4828fc0107
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in 4114553654e0
# Removing intermediate container 4114553654e0
#  ---> cf90b65689cb
# Step 4/19 : WORKDIR /
#  ---> Running in 2e65bec3d21a
# Removing intermediate container 2e65bec3d21a
#  ---> 328e28ccbcba
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 02b391e27dbc
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 72d4b08341cc
# Removing intermediate container 72d4b08341cc
#  ---> b6b3634e2fc4
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> f6e4c0759a47
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_f4d34986fac5bfa888344d2bd24de657 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 0f78f4ee23cd
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# tk-8.6.11            | 3.0 MB    |            |   0%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# wheel-0.37.0         | 33 KB     |            |   0%
# wheel-0.37.0         | 33 KB     | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# ca-certificates-2021 | 115 KB    |            |   0%
# ca-certificates-2021 | 115 KB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ####1      |  41%
# python-3.6.2         | 23.6 MB   | #########  |  90%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_f4d34986fac5bfa888344d2bd24de657/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.xms8y2px.requirements.txt']
# Pip subprocess output:
# Collecting azureml-core
#   Downloading azureml_core-1.37.0-py3-none-any.whl (2.5 MB)
# Collecting azureml-dataset-runtime
#   Downloading azureml_dataset_runtime-1.37.0-py3-none-any.whl (3.5 kB)
# Collecting keras==2.4.3
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Collecting tensorflow==2.4.3
#   Downloading tensorflow-2.4.3-cp36-cp36m-manylinux2010_x86_64.whl (394.5 MB)
# Collecting numpy
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
# Collecting pandas
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting matplotlib
#   Downloading matplotlib-3.3.4-cp36-cp36m-manylinux1_x86_64.whl (11.5 MB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting h5py
#   Downloading h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
# Collecting scipy>=0.14
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: wheel~=0.35 in /azureml-envs/azureml_f4d34986fac5bfa888344d2bd24de657/lib/python3.6/site-packages (from tensorflow==2.4.3->-r /azureml-environment-setup/condaenv.xms8y2px.requirements.txt (line 4)) (0.37.0)
# Collecting h5py
#   Downloading h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp36-cp36m-manylinux2014_x86_64.whl (3.8 MB)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting msal-extensions<0.4,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
# Collecting urllib3<=1.26.7,>=1.23
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting argcomplete~=1.8
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting azure-mgmt-storage<20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-19.0.0-py2.py3-none-any.whl (1.8 MB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.16.0-py2.py3-none-any.whl (78 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting pyopenssl<22.0.0
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-core<1.21
#   Downloading azure_core-1.20.1-py2.py3-none-any.whl (177 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# ...
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_f4d34986fac5bfa888344d2bd24de657
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 0f78f4ee23cd
#  ---> 7aab05b2c350
# Step 9/19 : ENV PATH /azureml-envs/azureml_f4d34986fac5bfa888344d2bd24de657/bin:$PATH
#  ---> Running in fc1ae9b4f98e
# Removing intermediate container fc1ae9b4f98e
#  ---> cd158b32fb17
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> a4085029950a
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in d84b5ec03a41
# Copying environment context
# Removing intermediate container d84b5ec03a41
#  ---> 685467dcf66a
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 4294b739158e
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_f4d34986fac5bfa888344d2bd24de657
#  ---> Running in e0f9e677bfb0
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container e0f9e677bfb0
#  ---> 8ac45111cd42
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_f4d34986fac5bfa888344d2bd24de657
#  ---> Running in 33929d8aa146
# Removing intermediate container 33929d8aa146
#  ---> 25eec7cf92db
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_f4d34986fac5bfa888344d2bd24de657/lib:$LD_LIBRARY_PATH
#  ---> Running in 590e50e62b78
# Removing intermediate container 590e50e62b78
#  ---> 0d2ce5f13bb4
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 5844453cef1d
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 1815a5ed84bc
# Removing intermediate container 1815a5ed84bc
#  ---> d2e65651118a
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in c9f5f5969345
# Removing intermediate container c9f5f5969345
#  ---> a9cb5febe6e6
# Step 19/19 : CMD ["bash"]
#  ---> Running in 1a8ec13ecb53
# Removing intermediate container 1a8ec13ecb53
#  ---> f8496d37826d
# Successfully built f8496d37826d
# Successfully tagged 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023:latest
# Successfully tagged 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023:1
# 2021/12/14 00:27:07 Successfully executed container: acb_step_0
# 2021/12/14 00:27:07 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/12/14 00:27:07 Pushing image: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023:1, attempt 1
# The push refers to repository [3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023]
# 70a6fec00c4e: Preparing
# 2ca2dca7450e: Preparing
# 3c6a5b46f013: Preparing
# 197483396bab: Preparing
# 386ce18f78cc: Preparing
# 103464b6d4b8: Preparing
# e7da580c9542: Preparing
# 25a57a012b97: Preparing
# 11c3a6727203: Preparing
# 3c50432f3f31: Preparing
# 311c5d6a5fbd: Preparing
# 510d9bebb038: Preparing
# ae7a6b62e247: Preparing
# 98fed88a80e7: Preparing
# e2015ea1a701: Preparing
# f7df5bbbf80f: Preparing
# 17773ff7b0e9: Preparing
# 824bf068fd3d: Preparing
# 103464b6d4b8: Waiting
# e7da580c9542: Waiting
# 25a57a012b97: Waiting
# 11c3a6727203: Waiting
# 3c50432f3f31: Waiting
# 311c5d6a5fbd: Waiting
# 510d9bebb038: Waiting
# ae7a6b62e247: Waiting
# 98fed88a80e7: Waiting
# e2015ea1a701: Waiting
# f7df5bbbf80f: Waiting
# 824bf068fd3d: Waiting
# 17773ff7b0e9: Waiting
# 3c6a5b46f013: Pushed
# 70a6fec00c4e: Pushed
# 197483396bab: Pushed
# 2ca2dca7450e: Pushed
# 25a57a012b97: Pushed
# 103464b6d4b8: Pushed
# e7da580c9542: Pushed
# 11c3a6727203: Pushed
# 3c50432f3f31: Pushed
# 311c5d6a5fbd: Pushed
# 510d9bebb038: Pushed
# ae7a6b62e247: Pushed
# f7df5bbbf80f: Pushed
# e2015ea1a701: Pushed
# 824bf068fd3d: Pushed
# 98fed88a80e7: Pushed
# 17773ff7b0e9: Pushed
#
# 386ce18f78cc: Pushed
# 1: digest: sha256:63c5d80304b65adb7d25448cfbaf2ea9245bae0e411a762a7c25734000ac17e1 size: 4100
# 2021/12/14 00:28:54 Successfully pushed image: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023:1
# 2021/12/14 00:28:54 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/12/14 00:28:54 Pushing image: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023:latest, attempt 1
# The push refers to repository [3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023]
# 70a6fec00c4e: Preparing
# 2ca2dca7450e: Preparing
# 3c6a5b46f013: Preparing
# 197483396bab: Preparing
# 386ce18f78cc: Preparing
# 103464b6d4b8: Preparing
# e7da580c9542: Preparing
# 25a57a012b97: Preparing
# 11c3a6727203: Preparing
# 3c50432f3f31: Preparing
# 311c5d6a5fbd: Preparing
# 510d9bebb038: Preparing
# ae7a6b62e247: Preparing
# 98fed88a80e7: Preparing
# e2015ea1a701: Preparing
# f7df5bbbf80f: Preparing
# 17773ff7b0e9: Preparing
# 824bf068fd3d: Preparing
# 103464b6d4b8: Waiting
# e7da580c9542: Waiting
# 25a57a012b97: Waiting
# 11c3a6727203: Waiting
# 3c50432f3f31: Waiting
# 311c5d6a5fbd: Waiting
# 510d9bebb038: Waiting
# ae7a6b62e247: Waiting
# 98fed88a80e7: Waiting
# e2015ea1a701: Waiting
# f7df5bbbf80f: Waiting
# 17773ff7b0e9: Waiting
# 824bf068fd3d: Waiting
# 386ce18f78cc: Layer already exists
# 3c6a5b46f013: Layer already exists
# 197483396bab: Layer already exists
# 70a6fec00c4e: Layer already exists
# 11c3a6727203: Layer already exists
# 25a57a012b97: Layer already exists
# e7da580c9542: Layer already exists
# 103464b6d4b8: Layer already exists
# 510d9bebb038: Layer already exists
# ae7a6b62e247: Layer already exists
# 311c5d6a5fbd: Layer already exists
# 3c50432f3f31: Layer already exists
# 98fed88a80e7: Layer already exists
# f7df5bbbf80f: Layer already exists
# e2015ea1a701: Layer already exists
# 17773ff7b0e9: Layer already exists
# 824bf068fd3d: Layer already exists
# 2ca2dca7450e: Layer already exists
# latest: digest: sha256:63c5d80304b65adb7d25448cfbaf2ea9245bae0e411a762a7c25734000ac17e1 size: 4100
# 2021/12/14 00:28:57 Successfully pushed image: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io/azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023:latest
# 2021/12/14 00:28:57 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 149.364903)
# 2021/12/14 00:28:57 Populating digests for step ID: acb_step_0...
# 2021/12/14 00:28:58 Successfully populated digests for step ID: acb_step_0
# 2021/12/14 00:28:58 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 106.868912)
# 2021/12/14 00:28:58 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.950683)
# 2021/12/14 00:28:58 The following dependencies were found:
# 2021/12/14 00:28:58
# - image:
#     registry: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io
#     repository: azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023
#     tag: latest
#     digest: sha256:63c5d80304b65adb7d25448cfbaf2ea9245bae0e411a762a7c25734000ac17e1
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20211124.v1
#     digest: sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
#   git: {}
# - image:
#     registry: 3cc67b89be9b4c01b60e2886ea6ead62.azurecr.io
#     repository: azureml/azureml_40f8050cb78c2972b6ed1dfdf0cb3023
#     tag: "1"
#     digest: sha256:63c5d80304b65adb7d25448cfbaf2ea9245bae0e411a762a7c25734000ac17e1
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20211124.v1
#     digest: sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
#   git: {}
#
#
# Run ID: ca8 was successful after 4m24s
#
# StepRun(train step) Execution Summary
# ======================================
# StepRun( train step ) Status: Finished
#
# Warnings:
# This run might be using a new job runtime with improved performance and error reporting. The logs from your script are in user_logs/std_log.txt. Please let us know if you run into any issues, and if you would like to opt-out, please add the environment variable AZUREML_COMPUTE_USE_COMMON_RUNTIME to the environment variables section of the job and set its value to the string "false"
# {'runId': 'bbd04b2a-d9a0-44d8-af56-6efd5c34f50a', 'target': 'gpu-cluster', 'status': 'Completed', 'startTimeUtc': '2021-12-14T00:29:54.713722Z', 'endTimeUtc': '2021-12-14T00:32:36.119317Z', 'services': {}, 'warnings': [{'message': 'This run might be using a new job runtime with improved performance and error reporting. The logs from your script are in user_logs/std_log.txt. Please let us know if you run into any issues, and if you would like to opt-out, please add the environment variable AZUREML_COMPUTE_USE_COMMON_RUNTIME to the environment variables section of the job and set its value to the string "false"'}], 'properties': {'ContentSnapshotId': '652ac928-f31c-4986-85cc-0966f10e110c', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '8ff6582c-1c97-4741-b72b-8d8cde628cee', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '600ab4e1', 'azureml.pipelinerunid': '39236fa9-d0ba-46c0-a840-02debd38aa04', 'azureml.pipeline': '39236fa9-d0ba-46c0-a840-02debd38aa04', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '8cc5ec10-5a5e-4031-93d5-a305997cc2b7'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'prepared_fashion_ds', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['DatasetConsumptionConfig:prepared_fashion_ds'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'gpu-cluster', 'dataReferences': {}, 'data': {'prepared_fashion_ds': {'dataLocation': {'dataset': {'id': '8cc5ec10-5a5e-4031-93d5-a305997cc2b7', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Direct', 'environmentVariableName': 'prepared_fashion_ds', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': 2592000, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'keras-env', 'version': 'Autosave_2021-12-14T00:24:31Z_e3627fa8', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', {'pip': ['azureml-core', 'azureml-dataset-runtime', 'keras==2.4.3', 'tensorflow==2.4.3', 'numpy', 'scikit-learn', 'pandas', 'matplotlib']}], 'name': 'azureml_f4d34986fac5bfa888344d2bd24de657'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount' ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '39236fa9-d0ba-46c0-a840-02debd38aa04', 'status': 'Completed', 'startTimeUtc': '2021-12-14T00:12:52.399829Z', 'endTimeUtc': '2021-12-14T00:32:37.534181Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://basicws2storage0fbba2762.blob.core.windows.net/azureml/ExperimentRun/dcid.39236fa9-d0ba-46c0-a840-02debd38aa04/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=gqX4jfKKiNwm2jkLCibjvkKK873YWLTCGRCIl4Mr3N0%3D&skoid=6364d207-c9cb-4777-aac5-5defed76459f&sktid=5100e2c5-9fd5-492c-8e65-b9e2a0d8584f&skt=2021-12-13T23%3A33%3A57Z&ske=2021-12-15T07%3A43%3A57Z&sks=b&skv=2019-07-07&st=2021-12-14T00%3A22%3A41Z&se=2021-12-14T08%3A32%3A41Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://basicws2storage0fbba2762.blob.core.windows.net/azureml/ExperimentRun/dcid.39236fa9-d0ba-46c0-a840-02debd38aa04/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=rTfRGRt3SwSa%2FZBPEseofivGefpQ254tKgVtk3CkHlE%3D&skoid=6364d207-c9cb-4777-aac5-5defed76459f&sktid=5100e2c5-9fd5-492c-8e65-b9e2a0d8584f&skt=2021-12-13T23%3A33%3A57Z&ske=2021-12-15T07%3A43%3A57Z&sks=b&skv=2019-07-07&st=2021-12-14T00%3A22%3A41Z&se=2021-12-14T08%3A32%3A41Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://basicws2storage0fbba2762.blob.core.windows.net/azureml/ExperimentRun/dcid.39236fa9-d0ba-46c0-a840-02debd38aa04/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=7%2FrBjOt8jWx%2BEpM52qyvWHQwT03QIneEfulWv35ZC8E%3D&skoid=6364d207-c9cb-4777-aac5-5defed76459f&sktid=5100e2c5-9fd5-492c-8e65-b9e2a0d8584f&skt=2021-12-13T23%3A33%3A57Z&ske=2021-12-15T07%3A43%3A57Z&sks=b&skv=2019-07-07&st=2021-12-14T00%3A22%3A41Z&se=2021-12-14T08%3A32%3A41Z&sp=r'}, 'submittedBy': 'Axel Sirota'}
# 'Finished'

# %%
run.find_step_run('train step')[0].get_metrics()
# Out:
# {'Loss': [0.8421418070793152,
#   0.5300726294517517,
#   0.4550732970237732,
#   0.4121553599834442,
#   0.3826228380203247,
#   0.3648979365825653,
#   0.34244516491889954,
#   0.33340883255004883,
#   0.319690465927124,
#   0.31032752990722656],
#  'Accuracy': [0.684268057346344,
#   0.802508533000946,
#   0.8324369192123413,
#   0.8477693200111389,
#   0.8613832592964172,
#   0.8654897809028625,
#   0.8735018968582153,
#   0.8778315782546997,
#   0.8825852870941162,
#   0.8860669136047363],
#  'Final test loss': 0.2672939896583557,
#  'Final test accuracy': 0.9014225602149963,
#  'Loss v.s. Accuracy': 'aml://artifactId/ExperimentRun/dcid.bbd04b2a-d9a0-44d8-af56-6efd5c34f50a/Loss v.s. Accuracy_1639441942.png'}

# %%
# get input datasets
prep_step = run.find_step_run('prepare step')[0]
inputs = prep_step.get_details()['inputDatasets']
input_dataset = inputs[0]['dataset']

# list the files referenced by input_dataset
input_dataset.to_path()
# Out:
# ['/mnist-fashion/t10k-images-idx3-ubyte',
#  '/mnist-fashion/t10k-labels-idx1-ubyte',
#  '/mnist-fashion/train-images-idx3-ubyte',
#  '/mnist-fashion/train-labels-idx1-ubyte']

# %%
fashion_ds = input_dataset.register(workspace = workspace,
                                    name = 'fashion_ds',
                                    description = 'image and label files from fashion mnist',
                                    create_new_version = True)
fashion_ds
# Out:
# {
#   "source": [
#     "https://data4mldemo6150520719.blob.core.windows.net/demo/mnist-fashion"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "2397f50f-c3cc-49e4-8b61-d5881c35a432",
#     "name": "fashion_ds",
#     "version": 1,
#     "description": "image and label files from fashion mnist",
#     "workspace": "Workspace.create(name='basic-ws-2', subscription_id='790907ce-38df-431c-9fce-11b9ec68781d', resource_group='test')"
#   }
# }

# %%
run.find_step_run('train step')[0].register_model(model_name = 'keras-model', model_path = 'outputs/model/', 
                                                  datasets =[('train test data',fashion_ds)])
# Out:
# Model(workspace=Workspace.create(name='basic-ws-2', subscription_id='790907ce-38df-431c-9fce-11b9ec68781d', resource_group='test'), name=keras-model, id=keras-model:1, version=1, tags={}, properties={})
